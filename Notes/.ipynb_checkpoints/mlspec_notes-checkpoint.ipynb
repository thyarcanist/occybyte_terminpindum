# %% [markdown]
# # Machine Learning Specialization Notes

# %% [markdown]
# ```python
# #my own thoughts, but this would mean that in machine learning, outliers you'd find in data would be instances of bias or a favorable situation, which is still a bias. Which is something that responsible AI tries to eliminate.
# ```
#
# ![image.png](attachment:e6892e49-3ba2-46e9-9184-c24603a882d2.png)
#
#
# - Cost Function Formula
#
# In linear regression, the first thing to figure out is the cost function.<br> The cost function tells how well the model is doing, to eventually make it better.
#
# In the model: f(x) = wx+b <br>
# w,b: parameters <br>
# b is the y-intercept
#
# ![image.png](attachment:2f2e6b06-73b4-4792-b73d-60fd33b1697a.png)
#
# The squared error cost function is the more commonly used cost function.
#
# ![image.png](attachment:0ba8a71e-28e8-475d-b134-3e2a929c50fa.png)
